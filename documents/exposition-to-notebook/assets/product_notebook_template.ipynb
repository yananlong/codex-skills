# %% [markdown]
# # Exposition to Notebook Template
#
# Starting point for a runnable, product-ready prototype notebook.

# %% [markdown]
# ## Goal
#
# - What should this notebook produce?
# - What does “success” look like?

# %%
import platform
import random
import sys

print("Python:", sys.version)
print("Platform:", platform.platform())

SEED = 0
random.seed(SEED)

try:
    import numpy as np  # type: ignore

    np.random.seed(SEED)
except Exception:
    np = None

# %% [markdown]
# ## Background / Exposition
#
# Paste or summarize the source exposition here (keep equations in LaTeX).

# %%
from __future__ import annotations

from typing import Any


def core(inputs: Any) -> Any:
    """Compute the primary output from the exposition."""
    return inputs

# %%
# TODO: Replace with real tests.
assert True
